# %% [markdown]
# # **INTRO TO STATISTICS**

# %% [markdown]
# Hello! In this notebook, we will try to cover the most basic statistical concepts and will do some fun codes to check if it really works.<br>
# So, the concepts we will cover here are:<br>
#
# 1. *Types of Statistical Learning: Descriptive & Inferential*
# 2. *Population and Sample*
# 3. *Estimation*
# 4. *Variables: Input Variables & Output Variables*
#
# Books we will be following:
# ```
# 1. James, G., Witten, D., Hastie, T., Tibshirani, R., & Taylor, J. (2023). An introduction to statistical learning: With applications in Python. Springer.
# 2. Hastie, T., Tibshirani, R.,, Friedman, J. (2009). The elements of statistical learning: data mining, inference and prediction. Springer.
# ```

# %% [markdown]
# ### 1. Types of Statistical Learning: Descriptive & Inferential
# Let's begin with an example of two university students, name Donny and Darcy. We have collected their last semester's grades for the same courses they have taken, number of classes they have attended, and the part-time job hour they spent each week. If I ask who did better in the course, or who was the busiest among them in the last semester, we can easily find out by looking at their grades and their time spent in the semester. Even if I ask what was the average grade or minimum work-time of them, we can answer that by doing some calculations. This means, we can describe or summarize Donny and Darcy's semester by their grades, attendance, and working hour. Therefore, **Descriptive Statistics** is a statistical process that can describe or summarize the data in a meaningful way which can be characterized.
# <br>
# However, if we were to determine who is a good student among Donny and Darcy from the given dataset, that would be a different case. Because, we cannot judge or conclude a student is good or bad just focusing on grades, attendance, and working time. It requires more logical data and evidence to deduce into such conclusion that we can be confident of what we say. Thus, **Inferential Statistics** is a statistical process that can take a sample from the data to deduce into logical conclusion which can be generalized.
# <br>
#
# | Type | Purpose | Context | Statistical Tools |
# |---|---|---|---|
# | **Descriptive Statistic** | Summarize observed data | Average grades, working ratio, etc. | Mean, Median, Mode, Standard Deviation, etc. |
# | **Inferential Statistic** | Make predictions or comparisons | Future grades, performance comparison etc. | Hypothesis testing, Regression, etc. |

# %% [markdown]
# #### Let's take the context of Donny and Darcy into a fun code to understand a bit more about basic statistical tools.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Generate Numpy arrays of each column

# Grade Column
grade = np.array([3.25, 3.81, 3.05, 3.92, 2.86,
                  2.75, 2.99, 3.35, 3.95, 3.99,
                  4.0, 4.0, 3.89, 3.82, 3.67])
# Attendance Column
class_num = np.array([40, 46, 38, 48, 33,
                     32, 39, 41, 47, 46,
                     48, 48, 48, 46, 45])
# Worktime Column
work = np.array([290, 280, 300, 260, 318,
                300, 296, 290, 290, 200,
                190, 300, 100, 260, 280])
# Check shapes
if grade.shape == class_num.shape == work.shape:
    print(f"All are same shape: {grade.shape}")
# Out:
# All are same shape: (15,)

# %%
data_table = np.array([grade, class_num, work]).T # Transpose for dataframing
data_table
# Out:
# array([[  3.25,  40.  , 290.  ],
#        [  3.81,  46.  , 280.  ],
#        [  3.05,  38.  , 300.  ],
#        [  3.92,  48.  , 260.  ],
#        [  2.86,  33.  , 318.  ],
#        [  2.75,  32.  , 300.  ],
#        [  2.99,  39.  , 296.  ],
#        [  3.35,  41.  , 290.  ],
#        [  3.95,  47.  , 290.  ],
#        [  3.99,  46.  , 200.  ],
#        [  4.  ,  48.  , 190.  ],
#        [  4.  ,  48.  , 300.  ],
#        [  3.89,  48.  , 100.  ],
#        [  3.82,  46.  , 260.  ],
#        [  3.67,  45.  , 280.  ]])

# %%
data_table.shape
# Out:
# (15, 3)

# %%
# Create a Pandas dataframe
data = pd.DataFrame(data_table, index=range(1, len(grade)+1),
                    columns=("Grade(/4.00)", "Attendance(/48H)", "Worktime(/320H)"),
                    dtype="float32")
data
# Out:
#     Grade(/4.00)  Attendance(/48H)  Worktime(/320H)
# 1           3.25              40.0            290.0
# 2           3.81              46.0            280.0
# 3           3.05              38.0            300.0
# 4           3.92              48.0            260.0
# 5           2.86              33.0            318.0
# 6           2.75              32.0            300.0
# 7           2.99              39.0            296.0
# 8           3.35              41.0            290.0
# 9           3.95              47.0            290.0
# 10          3.99              46.0            200.0
# 11          4.00              48.0            190.0
# 12          4.00              48.0            300.0
# 13          3.89              48.0            100.0
# 14          3.82              46.0            260.0
# 15          3.67              45.0            280.0

# %% [markdown]
# Let's do some fun statistical calculations and visualization!
# <br>
# We can use Pandas defined methods for descriptive statistics.

# %%
# Print Mean, Mode, and Median
avg_grade = data["Grade(/4.00)"].mean()
mode_att = data["Attendance(/48H)"].mode()
med_work = data["Worktime(/320H)"].median()

print(f"Mean of Grade Points\t: {avg_grade}\nMode of Attendance\t: {mode_att}\nMedian of Worktime\t: {med_work}")
# Out:
# Mean of Grade Points	: 3.5533335208892822
# Mode of Attendance	: 0    48.0
# dtype: float32
# Median of Worktime	: 290.0

# %% [markdown]
# Or, we could just call the `describe()` method to get all the basic descriptive stats

# %%
# Describe the dataframe
data.describe()
# Out:
#        Grade(/4.00)  Attendance(/48H)  Worktime(/320H)
# count     15.000000         15.000000        15.000000
# mean       3.553334         43.000000       263.600006
# std        0.461019          5.490251        57.857956
# min        2.750000         32.000000       100.000000
# 25%        3.150000         39.500000       260.000000
# 50%        3.810000         46.000000       290.000000
# 75%        3.935000         47.500000       298.000000
# max        4.000000         48.000000       318.000000

# %%
# Create a scatter plot with Attendance vs Grade
plt.figure(figsize=(10, 6))
plt.scatter(data["Grade(/4.00)"], data["Attendance(/48H)"], 
            s=150, alpha=0.6, edgecolors='black')
# Customize the plot
plt.title('Scatter Plot Example')
plt.xlabel('Grade')
plt.ylabel('Attendance')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
data.hist(bins=15, figsize=(12, 9), grid=False, color="teal", alpha=0.7)
plt.suptitle('Distribution of Data')
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
# Calculate Range & Quartiles of each column
range_grade = data["Grade(/4.00)"].max() - data["Grade(/4.00)"].min()
qrtl_grade = data["Grade(/4.00)"].quantile([0.25, 0.50, 0.75])

range_attn = data["Attendance(/48H)"].max() - data["Attendance(/48H)"].min()
qrtl_attn = data["Attendance(/48H)"].quantile([0.25, 0.50, 0.75])

range_work = data["Worktime(/320H)"].max() - data["Worktime(/320H)"].min()
qrtl_work = data["Worktime(/320H)"].quantile([0.25, 0.50, 0.75])

print(f"Range for column 'Grade(/4.00)'\t: {range_grade}")
print(f"Quartiles for column 'Grade(/4.00)'\t:\n{qrtl_grade}\n")
print(f"Range for column 'Attendance(/48H)'\t: {range_attn}")
print(f"Quartiles for column 'Attendance(/48H)'\t:\n{qrtl_attn}\n")
print(f"Range for column 'Worktime(/320H)'\t: {range_work}")
print(f"Quartiles for column 'Worktime(/320H)'\t:\n{qrtl_work}")
# Out:
# Range for column 'Grade(/4.00)'	: 1.25
# Quartiles for column 'Grade(/4.00)'	:
# 0.25    3.150
# 0.50    3.810
# 0.75    3.935
# Name: Grade(/4.00), dtype: float64
#
# Range for column 'Attendance(/48H)'	: 16.0
# Quartiles for column 'Attendance(/48H)'	:
# 0.25    39.5
# 0.50    46.0
# 0.75    47.5
# Name: Attendance(/48H), dtype: float64
#
# Range for column 'Worktime(/320H)'	: 218.0
# Quartiles for column 'Worktime(/320H)'	:
# 0.25    260.0
# 0.50    290.0
# 0.75    298.0
# Name: Worktime(/320H), dtype: float64

# %%
# Create a box plot for all numerical columns in the DataFrame
data.boxplot()
plt.title('Box Plot of Columns')
plt.ylabel('Value')
plt.show()

# %%
import seaborn as sns

# Using Seaborn for a more aesthetically pleasing box plot
sns.boxplot(data=data["Grade(/4.00)"], color="cornflowerblue")
plt.title('Seaborn Box Plot of Columns')
plt.ylabel('Value')
plt.show()
sns.boxplot(data=data["Attendance(/48H)"], color="tomato")
plt.show()
sns.boxplot(data=data["Worktime(/320H)"], color="seagreen")
plt.show()

# %% [markdown]
# ### 2. Population and Sample
# Let's say we want to know "_How many people in Halifax, NS likes a Blue Dodge Challenger car?_" There are almost 500,000 people living in Halifax as of 2025. It will indeed not be a feasible nor wise to ask all the 500,000 people whether they do like it or not. We almost certainly just can't! But we can randomly ask at least 100 people and record their answer: "_Yes_" or "_No_".
# <br>
# Therefore, **Population** in statistic is the entire group of individuals or items that is to be studied. While, **Sample** is just a smaller subset that represents the whole **Population** which is to be observed or recorded instead.
#
# <img src="contents/Population_and_Sample.png" align="center">_Figure: A visual representation of Population and Sample_</img>

# %% [markdown]
# ### 3. Estimation
#
# From the previous example, we do realize that it is almost impractical or impossible to measure or record every item from the population and that's why we choose a sample. That smaller subset of sample represents the whole population's perspective. Let's say after collecting data from the 100 people in Halifax, we found out 23 people out of 100 people liked having a blue Dodge Challenger car. So we can say that **_23% people liked having the blue car_**. This statement is not just a random guess; this is an informed assertion from a representing sample with actual statistical settings. **Estimation** is the process of using a sample data to make an educated conjecture or approximation about unknown characteristics of a larger population. It involves calculating an _Estimator_ or a _Rule_ by providing data from the sample to estimate for the larger population.
# <br>
# There are mainly _two types_ of Estimates in Statistics:
# 1. **Point Estimation:** It is the process of finding an approximate value of some characteristic (_Parameter_) of a population from random samples of the population. For example, the sample mean is a common point estimator for the unknown population mean.
# 2. **Interval Estimation:** It is the evaluation of a characteristic (_Parameter_) of a population by computing an interval, or a range of values, within which the characteristic is most likely to be located. For example, a confidence interval (CI), which indicates the probability (e.g., 95%) that the interval contains the true characteristic.

# %% [markdown]
# ### 4. Variables: Input Variables & Output Variables
# In stat, A **_Variable_** is a measurable characteristic, attribute, or feature of a person, object, or event that can take on a variety of values.
# <br>
# A variable itself may not be meaningful or understandable all the time. For example, say we have a person P's attribute gathered as variable A, B, and C. These variables can be of any datatype or any value. But how does these variables define a person is our concern. A and B could be Height and Weight and we can give a conclusion to that the person P's Height and Weight is A and B. But if C is an unknown variable that contains any positive Real Number from 0 to infinity, what conclusion could we add to that? Without knowing what C means, we can assume everything but cannot define anything.<br>
# Turned out, if we divide the Weight with the squared values of Height, it gives us the exact value in C. That's actually the person P's BMI score! But we didn't know that before. Even without knowing what the variable C is, could we have guessed it correctly? Hmm...oh yes! With statistics we actually can guess it!! It is what we learned before as _Estimation_.
# <br>
# To **_Estimate_** the BMI (variable C), we needed the Weight (variable A) and Height (variable B). Then we needed the equation or the estimator function  ```{Weight / Height^2}``` to estimate BMI (variable C). So in this context:
# - A and B are **_Input Variables_**: Which works as an input for the estimation function
# - C is the **_Output Variable_**: Which works as an output of the estimation function
#
# We can write:
# $$BMI (C) = f(Weight(A), Height(B))$$
# or simply,
# $$Y = f(X)$$
# Where, Y is the output of the estimator function of input X.

# %% [markdown]
# #### In the later notebooks, we will dive into the statistical tools more, eventually into inferential statistic!
